# %%
import pandas as pd
import datetime as dt
from datetime import datetime, timedelta
from suntime import Sun, SunTimeException
from datetime import datetime, timezone
import numpy as np
import glob
import os
import xarray as xr
from pathlib import Path

import gzip
import shutil


def select_daylight_data_juelich(startdate, enddate, path):
    '''
    What does it?
    Step one from the instructions:
    
    Creates a script that reads the files sups_joy_pyr00 (SW data) and sups_joy_pyrg00 (LW data)
    from the folder data/hatpro/jue/hdcp2/radiation_hdcp2 and selects values at the requested satellite time stamps, 
    and saves them in a ncdf file
    
    -> In a timeperiod (between startdate and enddate) opens the daily datasets and selects the timstamps with sunlight.
    Saves it as datasets in a given path. It creates new folders for every year if they do not already exist.
    e.g.: 'path/2018/sups_joy_pyrg00_l1_rlds_v01_daylight20180102000000.nc'
    
    input:
        - startdate: <string>: e.g.: '2020-01-01' 
        - enddate:   <string>: e.g.: '2020-03-02'
        - path:      <string>: where to save the nc-file eg.: 'savings/'

        
    ''' 

    #Range of the datas
    all_dates = pd.date_range(start=startdate,end=enddate)

    #coordinates of Juelich
    latitude = 50.908546
    longitude = 6.413536
    sun = Sun(latitude, longitude)

    for day in all_dates:
        
        
        #getting the time of sunrise +1 hour and the time of sunset - 1 hour. (result has information of timezone)
        sur_tzd = sun.get_local_sunrise_time(day) + timedelta(hours=1)
        sus_tzd = sun.get_local_sunset_time(day) - timedelta(hours=1)

        #delete timezonedesignator (Data from sup_joys are in UTC)
        sur = sur_tzd.replace(tzinfo=None)
        sus = sus_tzd.replace(tzinfo=None)
        #print(sur, 'sunrise')
        

        
        #get the day to string, to open the right file
        y = day.strftime('%Y')
        m = day.strftime('%m')
        d = day.strftime('%d')
        date = y + m + d + '000000.nc'

        #Open Files for LW and shortwave data and put them in one dataset
        
        #starting with LW
        #getting the names from the data. Some names have ..._v00_... and some ..._v01...
        fileName_LW = glob.glob('/data/hatpro/jue/hdcp2/radiation_hdcp2/'+ y +'/sups_joy_pyrg00_l1_rlds_v*_'+ date )
        #if there is no file for the day it goes to the next day
        if not fileName_LW:
            print(date + ' no LW-file for this day found')
            continue
            
        #open files 
        fileObj_LW = Path(str(fileName_LW[0]))
        if fileObj_LW.is_file() == True:
            ds_LW = xr.open_dataset(str(fileName_LW[0]))
            
            #in a really few cases it didn't work out to select times (I guess something is wrong with the datasets). Nevertheless that the program doesent stop there is a try:...
            try:
                ds_LW_light = ds_LW.sel(time=slice(sur, sus))
            
            except:
                print(str(fileName_LW[0]),' something went wrong with selecting sunlight time')
           
            #checking if path/folder already exists
            MYDIR = (path + y)
            CHECK_FOLDER = os.path.isdir(MYDIR)

            # If folder doesn't exist, then create it.
            if not CHECK_FOLDER:
                os.makedirs(MYDIR)
                print("created folder : ", MYDIR)
                
            #saving it as a new dataset 
            save_LW = path + y + '/sups_joy_pyrg00_l1_rlds_v_daylight' + date
            ds_LW_light.to_netcdf(save_LW)  

        else: 
            print('File not found')
            print(fileName[0]_LW)

        #SW
        #getting the names from the data. Some names have ..._v00_... and some ..._v01...
        fileName_SW = glob.glob('/data/hatpro/jue/hdcp2/radiation_hdcp2/'+ y +'/sups_joy_pyr00_l1_rsds_v*_'+ date )
        #if there is no file for the day it goes to the next day
        if not fileName_SW:
            print(date + ' no SW-file for this day found')
            continue
            
        #open files 
        fileObj_SW = Path(str(fileName_SW[0]))
        if fileObj_SW.is_file() == True:
            ds_SW = xr.open_dataset(str(fileName_SW[0]))
            
            #in a really few cases it didn't work out to select times (I guess something is wrong with the datasets). Nevertheless that the program doesent stop there is a try:...
            try:
                ds_SW_light = ds_SW.sel(time=slice(sur, sus))
            
            except:
                print(str(fileName_LW[0]),' something went wrong with selecting sunlight time')
           
            #checking if path/folder already exists
            MYDIR = (path + y)
            CHECK_FOLDER = os.path.isdir(MYDIR)

            # If folder doesn't exist, then create it.
            if not CHECK_FOLDER:
                os.makedirs(MYDIR)
                print("created folder : ", MYDIR)
                
            #saving it as a new dataset 
            save_SW = path + y + '/sups_joy_pyr00_l1_rsds_v_daylight' + date
            ds_SW_light.to_netcdf(save_SW)  

        else: 
            print('File not found')
            print(fileName[0]) 

def select_daylight_solarpanel_data(startdate, enddate, path):
    '''
    What does it?
    Step two from the instructions
    
    -> In a timeperiod (between startdate and enddate) unzips the daily datasets, opens them and selects the timstamps with sunlight.
    Saves it as datasets in a given path. It creates new folders for every year if they do not already exist.
    e.g.: 'path/2016/details20161005.nc'
    
    input:
        - startdate: <string>: e.g.: '2020-01-01'  Only datas in Year 2016, 2017, 2020, 2021, 2022
        - enddate:   <string>: e.g.: '2020-03-02'
        - path:      <string>: where to save the nc-file eg.: 'savings1/'

        
    ''' 

    #Range of the datas
    all_dates = pd.date_range(start=startdate,end=enddate)

    #coordinates of Juelich
    latitude = 50.908546
    longitude = 6.413536
    sun = Sun(latitude, longitude)

    for day in all_dates:
        ds = xr.Dataset()
        ds_light = xr.Dataset()

        
        #getting the time of sunrise +1 hour and the time of sunset - 1 hour. (result has information of timezone)
        sur_tzd = sun.get_local_sunrise_time(day) + timedelta(hours=1)
        sus_tzd = sun.get_local_sunset_time(day) - timedelta(hours=1)

        #delete timezonedesignator (Data from sup_joys are in UTC)
        sur = sur_tzd.replace(tzinfo=None)
        sus = sus_tzd.replace(tzinfo=None)
        #print(sur, 'sunrise')
        

        
        #get the day to string, to open the right file
        y = day.strftime('%Y')
        m = day.strftime('%m')
        d = day.strftime('%d')
        date = y + m + d 


        #Unzipp the data and saving them in between
        fileName = '/data/obs/site/jue/pvm/l1/' + y + '/' + m + '/details' + date + '.nc.gz'
        fileObj = Path(fileName)
        if fileObj.is_file() == True:
            with gzip.open('/data/obs/site/jue/pvm/l1/' + y + '/' + m + '/details' + date + '.nc.gz', 'rb') as f_in:
                with open('date.nc', 'wb') as f_out:
                    shutil.copyfileobj(f_in, f_out)
                    
        else: 
            print('File not found: ', fileName)
            continue
       
    
        #open data
        if fileObj.is_file() == True:
            ds = xr.open_dataset('date.nc')
 
        else: 
            print(date, ' File not found: probably something went wrong with unzipping them')
            continue
            
        ds_light = ds.sel(time10s=slice(sur, sus), time60s=slice(sur, sus))
        

        
        #checking if path/folder already exists
        MYDIR = (path + y)
        CHECK_FOLDER = os.path.isdir(MYDIR)

        # If folder doesn't exist, then create it.
        if not CHECK_FOLDER:
            os.makedirs(MYDIR)
            print("created folder : ", MYDIR)

        #saving it as a new dataset 
        save = path + y + '/details' + date + '.nc'
        try:
            ds_light.to_netcdf(save)  
            #print(date, 'saved')
        except:
            print(date, 'saving didnt work')
        

    # Deleting the in between unzipped file
    file_path = 'date.nc'
    os.remove(file_path)

# %%
select_daylight_data_juelich('2011-01-01', '2022-06-01', 'savings/')
  

select_daylight_solarpanel_data('2016-10-01', '2017-10-30', 'savings1/')
# Out:
# 20110101000000.nc no LW-file for this day found
# 20110102000000.nc no LW-file for this day found
# 20110103000000.nc no LW-file for this day found
# 20110104000000.nc no LW-file for this day found
# 20110105000000.nc no LW-file for this day found
# 20110106000000.nc no LW-file for this day found
# 20110107000000.nc no LW-file for this day found
# 20110108000000.nc no LW-file for this day found
# 20110109000000.nc no LW-file for this day found
# 20110110000000.nc no LW-file for this day found
# 20110111000000.nc no LW-file for this day found
# 20110112000000.nc no LW-file for this day found
# 20110113000000.nc no LW-file for this day found
# 20110114000000.nc no LW-file for this day found
# 20110115000000.nc no LW-file for this day found
# 20110116000000.nc no LW-file for this day found
# 20110117000000.nc no LW-file for this day found
# 20110118000000.nc no LW-file for this day found
# 20110119000000.nc no LW-file for this day found
# 20110120000000.nc no LW-file for this day found
# 20110121000000.nc no LW-file for this day found
# 20110122000000.nc no LW-file for this day found
# 20110123000000.nc no LW-file for this day found
# 20110124000000.nc no LW-file for this day found
# 20110125000000.nc no LW-file for this day found
# 20110126000000.nc no LW-file for this day found
# 20110127000000.nc no LW-file for this day found
# 20110128000000.nc no LW-file for this day found
# 20110129000000.nc no LW-file for this day found
# 20110130000000.nc no LW-file for this day found
# 20110131000000.nc no LW-file for this day found
# 20110201000000.nc no LW-file for this day found
# 20110202000000.nc no LW-file for this day found
# 20110203000000.nc no LW-file for this day found
# 20110204000000.nc no LW-file for this day found
# 20110205000000.nc no LW-file for this day found
# 20110206000000.nc no LW-file for this day found
# 20110207000000.nc no LW-file for this day found
# 20110208000000.nc no LW-file for this day found
# 20110209000000.nc no LW-file for this day found
# 20110210000000.nc no LW-file for this day found
# 20110211000000.nc no LW-file for this day found
# 20110212000000.nc no LW-file for this day found
# 20110213000000.nc no LW-file for this day found
# 20110214000000.nc no LW-file for this day found
# 20110215000000.nc no LW-file for this day found
# 20110216000000.nc no LW-file for this day found
# 20110217000000.nc no LW-file for this day found
# 20110218000000.nc no LW-file for this day found
# 20110219000000.nc no LW-file for this day found
# 20110220000000.nc no LW-file for this day found
# 20110221000000.nc no LW-file for this day found
# 20110222000000.nc no LW-file for this day found
# 20110223000000.nc no LW-file for this day found
# 20110224000000.nc no LW-file for this day found
# 20110225000000.nc no LW-file for this day found
# 20110226000000.nc no LW-file for this day found
# 20110227000000.nc no LW-file for this day found
# 20110228000000.nc no LW-file for this day found
# 20110301000000.nc no LW-file for this day found
# 20110302000000.nc no LW-file for this day found
# 20110303000000.nc no LW-file for this day found
# 20110304000000.nc no LW-file for this day found
# 20110305000000.nc no LW-file for this day found
# 20110306000000.nc no LW-file for this day found
# 20110307000000.nc no LW-file for this day found
# 20110308000000.nc no LW-file for this day found
# 20110309000000.nc no LW-file for this day found
# 20110310000000.nc no LW-file for this day found
# 20110311000000.nc no LW-file for this day found
# 20110312000000.nc no LW-file for this day found
# 20110313000000.nc no LW-file for this day found
# 20110314000000.nc no LW-file for this day found
# 20110315000000.nc no LW-file for this day found
# 20110316000000.nc no LW-file for this day found
# 20110317000000.nc no LW-file for this day found
# 20110318000000.nc no LW-file for this day found
# 20110319000000.nc no LW-file for this day found
# 20110320000000.nc no LW-file for this day found
# 20110321000000.nc no LW-file for this day found
# 20110322000000.nc no LW-file for this day found
# 20110323000000.nc no LW-file for this day found
# 20110324000000.nc no LW-file for this day found
# 20110325000000.nc no LW-file for this day found
# 20110326000000.nc no LW-file for this day found
# 20110327000000.nc no LW-file for this day found
# 20110328000000.nc no LW-file for this day found
# 20110329000000.nc no LW-file for this day found
# 20110330000000.nc no LW-file for this day found
# 20110331000000.nc no LW-file for this day found
# 20110401000000.nc no LW-file for this day found
# 20110402000000.nc no LW-file for this day found
# 20110403000000.nc no LW-file for this day found
# 20110404000000.nc no LW-file for this day found
# 20110405000000.nc no LW-file for this day found
# 20110406000000.nc no LW-file for this day found
# 20110407000000.nc no LW-file for this day found
# 20110408000000.nc no LW-file for this day found
# 20110409000000.nc no LW-file for this day found
# 20110410000000.nc no LW-file for this day found
# 20110411000000.nc no LW-file for this day found
# 20110412000000.nc no LW-file for this day found
# 20110413000000.nc no LW-file for this day found
# 20110414000000.nc no LW-file for this day found
# 20110415000000.nc no LW-file for this day found
# 20110416000000.nc no LW-file for this day found
# 20110417000000.nc no LW-file for this day found
# 20110418000000.nc no LW-file for this day found
# 20110419000000.nc no LW-file for this day found
# 20110420000000.nc no LW-file for this day found
# 20110421000000.nc no LW-file for this day found
# 20110422000000.nc no LW-file for this day found
# 20110423000000.nc no LW-file for this day found
# 20110424000000.nc no LW-file for this day found
# 20110425000000.nc no LW-file for this day found
# 20110426000000.nc no LW-file for this day found
# 20110427000000.nc no LW-file for this day found
# 20110428000000.nc no LW-file for this day found
# 20110429000000.nc no LW-file for this day found
# 20110430000000.nc no LW-file for this day found
# 20110501000000.nc no LW-file for this day found
# 20110502000000.nc no LW-file for this day found
# 20110503000000.nc no LW-file for this day found
# 20110504000000.nc no LW-file for this day found
# 20110505000000.nc no LW-file for this day found
# 20110506000000.nc no LW-file for this day found
# 20110507000000.nc no LW-file for this day found
# 20110508000000.nc no LW-file for this day found
# 20110509000000.nc no LW-file for this day found
# 20110510000000.nc no LW-file for this day found
# 20110511000000.nc no LW-file for this day found
# 20110512000000.nc no LW-file for this day found
# 20110513000000.nc no LW-file for this day found
# 20110514000000.nc no LW-file for this day found
# 20110515000000.nc no LW-file for this day found
# 20110516000000.nc no LW-file for this day found
# 20110517000000.nc no LW-file for this day found
# 20110518000000.nc no LW-file for this day found
# 20110519000000.nc no LW-file for this day found
# 20110520000000.nc no LW-file for this day found
# 20110521000000.nc no LW-file for this day found
# 20110522000000.nc no LW-file for this day found
# 20110523000000.nc no LW-file for this day found
# 20110524000000.nc no LW-file for this day found
# 20110525000000.nc no LW-file for this day found
# 20110526000000.nc no LW-file for this day found
# 20110527000000.nc no LW-file for this day found
# 20110528000000.nc no LW-file for this day found
# 20110529000000.nc no LW-file for this day found
# 20110530000000.nc no LW-file for this day found
# 20110531000000.nc no LW-file for this day found
# 20110601000000.nc no LW-file for this day found
# 20110602000000.nc no LW-file for this day found
# 20110603000000.nc no LW-file for this day found
# 20110604000000.nc no LW-file for this day found
# 20110605000000.nc no LW-file for this day found
# 20110606000000.nc no LW-file for this day found
# 20110607000000.nc no LW-file for this day found
# 20110608000000.nc no LW-file for this day found
# 20110609000000.nc no LW-file for this day found
# 20110610000000.nc no LW-file for this day found
# 20110611000000.nc no LW-file for this day found
# 20110612000000.nc no LW-file for this day found
# 20110613000000.nc no LW-file for this day found
# 20110614000000.nc no LW-file for this day found
# 20110615000000.nc no LW-file for this day found
# 20110616000000.nc no LW-file for this day found
# 20110617000000.nc no LW-file for this day found
# 20110618000000.nc no LW-file for this day found
# 20110619000000.nc no LW-file for this day found
# 20110620000000.nc no LW-file for this day found
# 20110621000000.nc no LW-file for this day found
# 20110622000000.nc no LW-file for this day found
# 20110623000000.nc no LW-file for this day found
# 20110624000000.nc no LW-file for this day found
# 20110625000000.nc no LW-file for this day found
# 20110626000000.nc no LW-file for this day found
# 20110627000000.nc no LW-file for this day found
# 20110628000000.nc no LW-file for this day found
# 20110629000000.nc no LW-file for this day found
# 20110630000000.nc no LW-file for this day found
# 20110701000000.nc no LW-file for this day found
# 20110702000000.nc no LW-file for this day found
# 20110703000000.nc no LW-file for this day found
# 20110704000000.nc no LW-file for this day found
# 20110705000000.nc no LW-file for this day found
# 20110706000000.nc no LW-file for this day found
# 20110707000000.nc no LW-file for this day found
# 20110708000000.nc no LW-file for this day found
# 20110709000000.nc no LW-file for this day found
# 20110710000000.nc no LW-file for this day found
# 20110711000000.nc no LW-file for this day found
# 20110712000000.nc no LW-file for this day found
# 20110713000000.nc no LW-file for this day found
# 20110714000000.nc no LW-file for this day found
# 20110715000000.nc no LW-file for this day found
# 20110716000000.nc no LW-file for this day found
# 20110717000000.nc no LW-file for this day found
# 20110718000000.nc no LW-file for this day found
# 20110719000000.nc no LW-file for this day found
# 20110720000000.nc no LW-file for this day found
# 20110721000000.nc no LW-file for this day found
# 20110722000000.nc no LW-file for this day found
# 20110723000000.nc no LW-file for this day found
# 20110724000000.nc no LW-file for this day found
# 20110725000000.nc no LW-file for this day found
# 20110726000000.nc no LW-file for this day found
# 20110727000000.nc no LW-file for this day found
# 20110728000000.nc no LW-file for this day found
# 20110729000000.nc no LW-file for this day found
# 20110730000000.nc no LW-file for this day found
# 20110731000000.nc no LW-file for this day found
# 20110801000000.nc no LW-file for this day found
# 20110802000000.nc no LW-file for this day found
# 20110803000000.nc no LW-file for this day found
# 20110804000000.nc no LW-file for this day found
# 20110805000000.nc no LW-file for this day found
# 20110806000000.nc no LW-file for this day found
# 20110807000000.nc no LW-file for this day found
# 20110808000000.nc no LW-file for this day found
# 20110809000000.nc no LW-file for this day found
# 20110810000000.nc no LW-file for this day found
# 20110811000000.nc no LW-file for this day found
# 20110812000000.nc no LW-file for this day found
# 20110813000000.nc no LW-file for this day found
# 20110814000000.nc no LW-file for this day found
# 20110815000000.nc no LW-file for this day found
# 20110816000000.nc no LW-file for this day found
# 20110817000000.nc no SW-file for this day found
# 20110818000000.nc no SW-file for this day found
# 20110819000000.nc no SW-file for this day found
# 20110820000000.nc no SW-file for this day found
# 20110821000000.nc no SW-file for this day found
# 20110822000000.nc no SW-file for this day found
# 20110823000000.nc no SW-file for this day found
# 20110824000000.nc no SW-file for this day found
# 20110825000000.nc no SW-file for this day found
# 20110826000000.nc no SW-file for this day found
# 20110827000000.nc no SW-file for this day found
# 20110828000000.nc no SW-file for this day found
# 20110829000000.nc no SW-file for this day found
# 20110830000000.nc no SW-file for this day found
# 20110831000000.nc no SW-file for this day found
# 20110901000000.nc no SW-file for this day found
# 20110902000000.nc no SW-file for this day found
# 20110903000000.nc no SW-file for this day found
# 20110904000000.nc no SW-file for this day found
# 20110905000000.nc no SW-file for this day found
# 20110906000000.nc no SW-file for this day found
# 20110907000000.nc no SW-file for this day found
# 20110908000000.nc no SW-file for this day found
# 20110909000000.nc no SW-file for this day found
# 20110910000000.nc no SW-file for this day found
# 20110911000000.nc no SW-file for this day found
# 20110912000000.nc no SW-file for this day found
# 20110913000000.nc no SW-file for this day found
# 20110914000000.nc no SW-file for this day found
# 20110915000000.nc no SW-file for this day found
# 20110916000000.nc no SW-file for this day found
# 20110917000000.nc no SW-file for this day found
# 20110918000000.nc no SW-file for this day found
# 20110919000000.nc no SW-file for this day found
# 20110920000000.nc no SW-file for this day found
# 20110921000000.nc no SW-file for this day found
# 20110922000000.nc no SW-file for this day found
# 20110923000000.nc no SW-file for this day found
# 20110924000000.nc no LW-file for this day found
# 20110925000000.nc no LW-file for this day found
# 20110926000000.nc no LW-file for this day found
# 20110927000000.nc no LW-file for this day found
# 20110928000000.nc no LW-file for this day found
# 20110929000000.nc no LW-file for this day found
# 20110930000000.nc no SW-file for this day found
# 20111001000000.nc no SW-file for this day found
# 20111002000000.nc no SW-file for this day found
# 20111003000000.nc no SW-file for this day found
# 20111004000000.nc no SW-file for this day found
# 20111005000000.nc no SW-file for this day found
# 20111006000000.nc no SW-file for this day found
# 20111007000000.nc no SW-file for this day found
# 20111008000000.nc no SW-file for this day found
# 20111009000000.nc no SW-file for this day found
# 20111010000000.nc no SW-file for this day found
# 20111011000000.nc no SW-file for this day found
# 20111012000000.nc no SW-file for this day found
# 20111013000000.nc no SW-file for this day found
# 20111014000000.nc no SW-file for this day found
# 20111015000000.nc no SW-file for this day found
# 20111016000000.nc no SW-file for this day found
# 20111017000000.nc no SW-file for this day found
# 20111018000000.nc no SW-file for this day found
# 20111019000000.nc no SW-file for this day found
# 20111020000000.nc no SW-file for this day found
# 20111021000000.nc no SW-file for this day found
# 20111022000000.nc no SW-file for this day found
# 20111023000000.nc no SW-file for this day found
# 20111024000000.nc no SW-file for this day found
# 20111025000000.nc no SW-file for this day found
# 20111026000000.nc no SW-file for this day found
# 20111027000000.nc no SW-file for this day found
# 20111028000000.nc no SW-file for this day found
# 20111029000000.nc no SW-file for this day found
# 20111030000000.nc no SW-file for this day found
# 20111031000000.nc no SW-file for this day found
# 20111101000000.nc no SW-file for this day found
# 20111102000000.nc no SW-file for this day found
# 20111103000000.nc no SW-file for this day found
# 20111104000000.nc no SW-file for this day found
# 20111105000000.nc no SW-file for this day found
# 20111106000000.nc no SW-file for this day found
# 20111107000000.nc no SW-file for this day found
# 20111108000000.nc no SW-file for this day found
# 20111109000000.nc no SW-file for this day found
# 20111110000000.nc no SW-file for this day found
# 20111111000000.nc no SW-file for this day found
# 20111112000000.nc no SW-file for this day found
# 20111113000000.nc no SW-file for this day found
# 20111114000000.nc no SW-file for this day found
# 20111115000000.nc no SW-file for this day found
# 20111116000000.nc no SW-file for this day found
# 20111117000000.nc no SW-file for this day found
# 20111118000000.nc no SW-file for this day found
# 20111119000000.nc no SW-file for this day found
# 20111120000000.nc no SW-file for this day found
# 20111121000000.nc no SW-file for this day found
# 20111122000000.nc no SW-file for this day found
# 20111123000000.nc no SW-file for this day found
# 20111124000000.nc no SW-file for this day found
# 20111125000000.nc no SW-file for this day found
# 20111126000000.nc no SW-file for this day found
# 20111127000000.nc no SW-file for this day found
# 20111128000000.nc no SW-file for this day found
# 20111129000000.nc no SW-file for this day found
# 20111130000000.nc no SW-file for this day found
# 20111201000000.nc no SW-file for this day found
# 20111202000000.nc no SW-file for this day found
# 20111203000000.nc no SW-file for this day found
# 20111204000000.nc no SW-file for this day found
# 20111205000000.nc no SW-file for this day found
# 20111206000000.nc no SW-file for this day found
# 20111207000000.nc no SW-file for this day found
# 20111208000000.nc no SW-file for this day found
# 20111209000000.nc no SW-file for this day found
# 20111210000000.nc no SW-file for this day found
# 20111211000000.nc no SW-file for this day found
# 20111212000000.nc no SW-file for this day found
# 20111213000000.nc no SW-file for this day found
# 20111214000000.nc no SW-file for this day found
# 20111215000000.nc no SW-file for this day found
# 20111216000000.nc no SW-file for this day found
# 20111217000000.nc no SW-file for this day found
# 20111218000000.nc no SW-file for this day found
# 20111219000000.nc no SW-file for this day found
# 20111220000000.nc no SW-file for this day found
# 20111221000000.nc no SW-file for this day found
# 20111222000000.nc no SW-file for this day found
# 20111223000000.nc no SW-file for this day found
# 20111224000000.nc no SW-file for this day found
# 20111225000000.nc no SW-file for this day found
# 20111226000000.nc no SW-file for this day found
# 20111227000000.nc no SW-file for this day found
# 20111228000000.nc no SW-file for this day found
# 20111229000000.nc no SW-file for this day found
# 20111230000000.nc no SW-file for this day found
# 20111231000000.nc no SW-file for this day found
# 20120101000000.nc no SW-file for this day found
# 20120102000000.nc no SW-file for this day found
# 20120103000000.nc no SW-file for this day found
# 20120104000000.nc no SW-file for this day found
# 20120105000000.nc no SW-file for this day found
# 20120106000000.nc no SW-file for this day found
# 20120107000000.nc no SW-file for this day found
# 20120108000000.nc no SW-file for this day found
# 20120109000000.nc no SW-file for this day found
# 20120110000000.nc no SW-file for this day found
# 20120111000000.nc no SW-file for this day found
# 20120112000000.nc no SW-file for this day found
# 20120113000000.nc no SW-file for this day found
# 20120114000000.nc no SW-file for this day found
# 20120115000000.nc no SW-file for this day found
# 20120116000000.nc no SW-file for this day found
# 20120117000000.nc no SW-file for this day found
# 20120118000000.nc no SW-file for this day found
# 20120119000000.nc no SW-file for this day found
# 20120120000000.nc no SW-file for this day found
# 20120121000000.nc no SW-file for this day found
# 20120122000000.nc no SW-file for this day found
# 20120123000000.nc no SW-file for this day found
# 20120124000000.nc no SW-file for this day found
# 20120125000000.nc no SW-file for this day found
# 20120126000000.nc no SW-file for this day found
# 20120127000000.nc no SW-file for this day found
# 20120128000000.nc no SW-file for this day found
# 20120129000000.nc no SW-file for this day found
# 20120130000000.nc no SW-file for this day found
# 20120131000000.nc no SW-file for this day found
# 20120201000000.nc no SW-file for this day found
# 20120202000000.nc no SW-file for this day found
# 20120203000000.nc no SW-file for this day found
# 20120204000000.nc no SW-file for this day found
# 20120205000000.nc no SW-file for this day found
# 20120206000000.nc no SW-file for this day found
# 20120207000000.nc no SW-file for this day found
# 20120208000000.nc no SW-file for this day found
# 20120209000000.nc no SW-file for this day found
# 20120210000000.nc no SW-file for this day found
# 20120211000000.nc no SW-file for this day found
# 20120212000000.nc no SW-file for this day found
# 20120213000000.nc no SW-file for this day found
# 20120214000000.nc no SW-file for this day found
# 20120215000000.nc no SW-file for this day found
# 20120216000000.nc no SW-file for this day found
# 20120217000000.nc no SW-file for this day found
# 20120218000000.nc no SW-file for this day found
# 20120219000000.nc no SW-file for this day found
# 20120220000000.nc no SW-file for this day found
# 20120221000000.nc no SW-file for this day found
# 20120222000000.nc no SW-file for this day found
# 20120223000000.nc no SW-file for this day found
# 20120224000000.nc no SW-file for this day found
# 20120225000000.nc no SW-file for this day found
# 20120226000000.nc no SW-file for this day found
# 20120227000000.nc no SW-file for this day found
# 20120228000000.nc no SW-file for this day found
# 20120229000000.nc no SW-file for this day found
# 20120301000000.nc no SW-file for this day found
# 20120302000000.nc no SW-file for this day found
# 20120303000000.nc no SW-file for this day found
# 20120304000000.nc no SW-file for this day found
# 20120305000000.nc no SW-file for this day found
# 20120306000000.nc no SW-file for this day found
# 20120307000000.nc no SW-file for this day found
# 20120308000000.nc no SW-file for this day found
# 20120309000000.nc no SW-file for this day found
# 20120310000000.nc no SW-file for this day found
# 20120311000000.nc no SW-file for this day found
# 20120312000000.nc no SW-file for this day found
# 20120313000000.nc no SW-file for this day found
# 20120314000000.nc no SW-file for this day found
# 20120315000000.nc no SW-file for this day found
# 20120316000000.nc no SW-file for this day found
# 20120317000000.nc no SW-file for this day found
# 20120318000000.nc no SW-file for this day found
# 20120319000000.nc no SW-file for this day found
# 20120320000000.nc no SW-file for this day found
# 20120321000000.nc no SW-file for this day found
# 20120322000000.nc no SW-file for this day found
# 20120323000000.nc no SW-file for this day found
# 20120324000000.nc no SW-file for this day found
# 20120325000000.nc no SW-file for this day found
# 20120326000000.nc no SW-file for this day found
# 20120327000000.nc no SW-file for this day found
# 20120328000000.nc no SW-file for this day found
# 20120329000000.nc no SW-file for this day found
# 20120330000000.nc no SW-file for this day found
# 20120331000000.nc no SW-file for this day found
# 20120401000000.nc no SW-file for this day found
# 20120402000000.nc no SW-file for this day found
# 20120403000000.nc no SW-file for this day found
# 20120404000000.nc no SW-file for this day found
# 20120405000000.nc no SW-file for this day found
# 20120406000000.nc no SW-file for this day found
# 20120407000000.nc no SW-file for this day found
# 20120408000000.nc no SW-file for this day found
# 20120409000000.nc no SW-file for this day found
# 20120410000000.nc no SW-file for this day found
# 20120411000000.nc no SW-file for this day found
# 20120412000000.nc no SW-file for this day found
# 20120413000000.nc no SW-file for this day found
# 20120414000000.nc no SW-file for this day found
# 20120415000000.nc no SW-file for this day found
# 20120416000000.nc no SW-file for this day found
# 20120417000000.nc no SW-file for this day found
# 20120418000000.nc no SW-file for this day found
# 20120419000000.nc no SW-file for this day found
# 20120420000000.nc no SW-file for this day found
# 20120421000000.nc no SW-file for this day found
# 20120422000000.nc no SW-file for this day found
# 20120423000000.nc no SW-file for this day found
# 20120424000000.nc no SW-file for this day found
# 20120425000000.nc no SW-file for this day found
# 20120426000000.nc no SW-file for this day found
# 20120427000000.nc no SW-file for this day found
# 20120428000000.nc no SW-file for this day found
# 20120429000000.nc no SW-file for this day found
# 20120430000000.nc no SW-file for this day found
# 20120501000000.nc no SW-file for this day found
# 20120502000000.nc no SW-file for this day found
# 20120503000000.nc no SW-file for this day found
# 20120504000000.nc no SW-file for this day found
# 20120505000000.nc no SW-file for this day found
# 20120506000000.nc no SW-file for this day found
# 20120507000000.nc no SW-file for this day found
# 20120508000000.nc no SW-file for this day found
# 20120509000000.nc no SW-file for this day found
# 20120510000000.nc no SW-file for this day found
# 20120511000000.nc no SW-file for this day found
# 20120512000000.nc no SW-file for this day found
# 20120513000000.nc no SW-file for this day found
# 20120514000000.nc no SW-file for this day found
# 20120515000000.nc no SW-file for this day found
# 20120516000000.nc no SW-file for this day found
# 20120517000000.nc no SW-file for this day found
# 20120518000000.nc no SW-file for this day found
# 20120519000000.nc no SW-file for this day found
# 20120520000000.nc no SW-file for this day found
# 20120521000000.nc no SW-file for this day found
# 20120522000000.nc no SW-file for this day found
# 20120523000000.nc no SW-file for this day found
# 20120524000000.nc no SW-file for this day found
# 20120525000000.nc no SW-file for this day found
# 20120526000000.nc no SW-file for this day found
# 20120527000000.nc no SW-file for this day found
# 20120528000000.nc no SW-file for this day found
# 20120529000000.nc no SW-file for this day found
# 20120530000000.nc no SW-file for this day found
# 20120531000000.nc no SW-file for this day found
# 20120601000000.nc no SW-file for this day found
# 20120602000000.nc no SW-file for this day found
# 20120603000000.nc no SW-file for this day found
# 20120604000000.nc no SW-file for this day found
# 20120605000000.nc no SW-file for this day found
# 20120606000000.nc no SW-file for this day found
# 20120607000000.nc no SW-file for this day found
# 20120608000000.nc no SW-file for this day found
# 20120609000000.nc no SW-file for this day found
# 20120610000000.nc no SW-file for this day found
# 20120611000000.nc no SW-file for this day found
# 20120612000000.nc no SW-file for this day found
# 20120613000000.nc no SW-file for this day found
# 20120614000000.nc no SW-file for this day found
# 20120615000000.nc no SW-file for this day found
# 20120616000000.nc no SW-file for this day found
# 20120617000000.nc no SW-file for this day found
# 20120618000000.nc no SW-file for this day found
# 20120619000000.nc no SW-file for this day found
# 20120620000000.nc no SW-file for this day found
# 20120621000000.nc no SW-file for this day found
# /data/hatpro/jue/hdcp2/radiation_hdcp2/2012/sups_joy_pyrg00_l1_rlds_v01_20120622000000.nc  something went wrong with selecting sunlight time
# 20120622000000.nc no SW-file for this day found
# 20120623000000.nc no SW-file for this day found
# 20120624000000.nc no SW-file for this day found
# 20120625000000.nc no SW-file for this day found
# 20120626000000.nc no SW-file for this day found
# 20120627000000.nc no SW-file for this day found
# 20120628000000.nc no SW-file for this day found
# 20120629000000.nc no SW-file for this day found
# 20120630000000.nc no SW-file for this day found
# 20120701000000.nc no SW-file for this day found
# 20120702000000.nc no SW-file for this day found
# 20120703000000.nc no SW-file for this day found
# 20120704000000.nc no SW-file for this day found
# 20120705000000.nc no SW-file for this day found
# 20120706000000.nc no SW-file for this day found
# 20120707000000.nc no SW-file for this day found
# 20120708000000.nc no SW-file for this day found
# 20120709000000.nc no SW-file for this day found
# 20120710000000.nc no SW-file for this day found
# 20120711000000.nc no SW-file for this day found
# 20120712000000.nc no SW-file for this day found
# 20120713000000.nc no SW-file for this day found
# 20120714000000.nc no SW-file for this day found
# 20120715000000.nc no SW-file for this day found
# 20120716000000.nc no SW-file for this day found
# 20120717000000.nc no SW-file for this day found
# 20120718000000.nc no SW-file for this day found
# 20120719000000.nc no SW-file for this day found
# 20120720000000.nc no SW-file for this day found
# 20120721000000.nc no SW-file for this day found
# 20120722000000.nc no SW-file for this day found
# 20120723000000.nc no SW-file for this day found
# 20120724000000.nc no SW-file for this day found
# 20120725000000.nc no SW-file for this day found
# 20120726000000.nc no SW-file for this day found
# 20120727000000.nc no SW-file for this day found
# 20120728000000.nc no SW-file for this day found
# 20120729000000.nc no SW-file for this day found
# 20120730000000.nc no SW-file for this day found
# 20120731000000.nc no SW-file for this day found
# 20120801000000.nc no SW-file for this day found
# 20120802000000.nc no SW-file for this day found
# 20130101000000.nc no SW-file for this day found
# 20130102000000.nc no SW-file for this day found
# 20130103000000.nc no SW-file for this day found
# 20130104000000.nc no SW-file for this day found
# 20130105000000.nc no SW-file for this day found
# 20130106000000.nc no SW-file for this day found
# 20130107000000.nc no SW-file for this day found
# 20130108000000.nc no SW-file for this day found
# 20130109000000.nc no SW-file for this day found
# 20130110000000.nc no SW-file for this day found
# 20130111000000.nc no SW-file for this day found
# 20130112000000.nc no SW-file for this day found
# 20130113000000.nc no SW-file for this day found
# 20130114000000.nc no SW-file for this day found
# 20130115000000.nc no SW-file for this day found
# 20130116000000.nc no SW-file for this day found
# 20130117000000.nc no SW-file for this day found
# 20130118000000.nc no SW-file for this day found
# 20130119000000.nc no SW-file for this day found
# 20130120000000.nc no SW-file for this day found
# 20130121000000.nc no SW-file for this day found
# 20130122000000.nc no SW-file for this day found
# 20130123000000.nc no SW-file for this day found
# 20130124000000.nc no SW-file for this day found
# 20130125000000.nc no SW-file for this day found
# 20130126000000.nc no SW-file for this day found
# 20130127000000.nc no SW-file for this day found
# 20130128000000.nc no SW-file for this day found
# 20130129000000.nc no SW-file for this day found
# 20130130000000.nc no SW-file for this day found
# 20130131000000.nc no SW-file for this day found
# 20130201000000.nc no SW-file for this day found
# 20130202000000.nc no SW-file for this day found
# 20130203000000.nc no SW-file for this day found
# 20130204000000.nc no SW-file for this day found
# 20130205000000.nc no SW-file for this day found
# 20130206000000.nc no SW-file for this day found
# 20130207000000.nc no SW-file for this day found
# 20130208000000.nc no SW-file for this day found
# 20130209000000.nc no SW-file for this day found
# 20130210000000.nc no SW-file for this day found
# 20130211000000.nc no SW-file for this day found
# 20130212000000.nc no SW-file for this day found
# 20130213000000.nc no SW-file for this day found
# 20130214000000.nc no SW-file for this day found
# 20130215000000.nc no SW-file for this day found
# 20130216000000.nc no SW-file for this day found
# 20130217000000.nc no SW-file for this day found
# 20130218000000.nc no SW-file for this day found
# 20130219000000.nc no SW-file for this day found
# 20130220000000.nc no SW-file for this day found
# 20130221000000.nc no SW-file for this day found
# 20130222000000.nc no SW-file for this day found
# 20130223000000.nc no SW-file for this day found
# 20130224000000.nc no SW-file for this day found
# 20130225000000.nc no SW-file for this day found
# 20130226000000.nc no SW-file for this day found
# 20130227000000.nc no SW-file for this day found
# 20130228000000.nc no SW-file for this day found
# 20130301000000.nc no SW-file for this day found
# 20130302000000.nc no SW-file for this day found
# 20130303000000.nc no SW-file for this day found
# 20130304000000.nc no SW-file for this day found
# 20130305000000.nc no SW-file for this day found
# 20130306000000.nc no SW-file for this day found
# 20130307000000.nc no SW-file for this day found
# 20130308000000.nc no SW-file for this day found
# 20130309000000.nc no SW-file for this day found
# 20130310000000.nc no SW-file for this day found
# 20130311000000.nc no SW-file for this day found
# 20130312000000.nc no SW-file for this day found
# 20130313000000.nc no SW-file for this day found
# 20130314000000.nc no SW-file for this day found
# 20130315000000.nc no SW-file for this day found
# 20130316000000.nc no SW-file for this day found
# 20130317000000.nc no SW-file for this day found
# 20130318000000.nc no SW-file for this day found
# 20130319000000.nc no SW-file for this day found
# 20130320000000.nc no SW-file for this day found
# 20130321000000.nc no SW-file for this day found
# 20130322000000.nc no SW-file for this day found
# 20130323000000.nc no SW-file for this day found
# 20130324000000.nc no SW-file for this day found
# 20130325000000.nc no SW-file for this day found
# 20130326000000.nc no SW-file for this day found
# 20130327000000.nc no SW-file for this day found
# 20130328000000.nc no SW-file for this day found
# 20130329000000.nc no SW-file for this day found
# 20130330000000.nc no SW-file for this day found
# 20130331000000.nc no SW-file for this day found
# 20130401000000.nc no SW-file for this day found
# 20130402000000.nc no SW-file for this day found
# 20130403000000.nc no SW-file for this day found
# 20130404000000.nc no SW-file for this day found
# 20130405000000.nc no SW-file for this day found
# 20130406000000.nc no SW-file for this day found
# 20130407000000.nc no SW-file for this day found
# 20130408000000.nc no SW-file for this day found
# 20130409000000.nc no SW-file for this day found
# 20130410000000.nc no SW-file for this day found
# 20130411000000.nc no SW-file for this day found
# 20130412000000.nc no SW-file for this day found
# 20130413000000.nc no SW-file for this day found
# 20130414000000.nc no SW-file for this day found
# 20130415000000.nc no SW-file for this day found
# 20130416000000.nc no SW-file for this day found
# 20130417000000.nc no SW-file for this day found
# 20130418000000.nc no SW-file for this day found
# 20130419000000.nc no SW-file for this day found
# 20130420000000.nc no SW-file for this day found
# 20130421000000.nc no SW-file for this day found
# 20130422000000.nc no SW-file for this day found
# 20130423000000.nc no SW-file for this day found
# 20130424000000.nc no SW-file for this day found
# 20130425000000.nc no SW-file for this day found
# 20130426000000.nc no SW-file for this day found
# 20130427000000.nc no SW-file for this day found
# 20130428000000.nc no SW-file for this day found
# 20130429000000.nc no SW-file for this day found
# 20130430000000.nc no SW-file for this day found
# 20130501000000.nc no SW-file for this day found
# 20130502000000.nc no SW-file for this day found
# 20130503000000.nc no SW-file for this day found
# 20130504000000.nc no SW-file for this day found
# 20130505000000.nc no SW-file for this day found
# 20130506000000.nc no SW-file for this day found
# 20130507000000.nc no SW-file for this day found
# 20130508000000.nc no SW-file for this day found
# 20130509000000.nc no SW-file for this day found
# 20130510000000.nc no SW-file for this day found
# 20130511000000.nc no SW-file for this day found
# 20130512000000.nc no SW-file for this day found
# 20130513000000.nc no SW-file for this day found
# 20130514000000.nc no SW-file for this day found
# 20130515000000.nc no SW-file for this day found
# 20130516000000.nc no SW-file for this day found
# 20130517000000.nc no SW-file for this day found
# 20130518000000.nc no SW-file for this day found
# 20130519000000.nc no SW-file for this day found
# 20130520000000.nc no SW-file for this day found
# 20130521000000.nc no SW-file for this day found
# 20130522000000.nc no SW-file for this day found
# 20130523000000.nc no SW-file for this day found
# 20130524000000.nc no SW-file for this day found
# 20130525000000.nc no SW-file for this day found
# 20130526000000.nc no SW-file for this day found
# 20130527000000.nc no SW-file for this day found
# 20130528000000.nc no SW-file for this day found
# 20130529000000.nc no SW-file for this day found
# 20130530000000.nc no SW-file for this day found
# 20130531000000.nc no SW-file for this day found
# 20130601000000.nc no SW-file for this day found
# 20130602000000.nc no SW-file for this day found
# 20130603000000.nc no SW-file for this day found
# 20130604000000.nc no SW-file for this day found
# 20130605000000.nc no SW-file for this day found
# 20130606000000.nc no SW-file for this day found
# 20130607000000.nc no SW-file for this day found
# 20130608000000.nc no SW-file for this day found
# 20130609000000.nc no SW-file for this day found
# 20130610000000.nc no SW-file for this day found
# 20130611000000.nc no SW-file for this day found
# 20130612000000.nc no SW-file for this day found
# 20130613000000.nc no SW-file for this day found
# 20130614000000.nc no SW-file for this day found
# 20130615000000.nc no SW-file for this day found
# 20130616000000.nc no SW-file for this day found
# 20130617000000.nc no SW-file for this day found
# 20130618000000.nc no SW-file for this day found
# 20130619000000.nc no SW-file for this day found
# 20130620000000.nc no SW-file for this day found
# 20130621000000.nc no SW-file for this day found
# 20130622000000.nc no SW-file for this day found
# 20130623000000.nc no SW-file for this day found
# 20130624000000.nc no SW-file for this day found
# 20130625000000.nc no SW-file for this day found
# 20130626000000.nc no SW-file for this day found
# 20130627000000.nc no SW-file for this day found
# 20130628000000.nc no SW-file for this day found
# 20130629000000.nc no SW-file for this day found
# 20130630000000.nc no SW-file for this day found
# 20130701000000.nc no LW-file for this day found
# 20130702000000.nc no LW-file for this day found
# 20130703000000.nc no LW-file for this day found
# 20130704000000.nc no LW-file for this day found
# 20130705000000.nc no LW-file for this day found
# 20130706000000.nc no LW-file for this day found
# 20130707000000.nc no LW-file for this day found
# 20130708000000.nc no LW-file for this day found
# 20130709000000.nc no LW-file for this day found
# 20130710000000.nc no LW-file for this day found
# 20130711000000.nc no LW-file for this day found
# 20130712000000.nc no LW-file for this day found
# 20130713000000.nc no LW-file for this day found
# 20130714000000.nc no LW-file for this day found
# 20130715000000.nc no LW-file for this day found
# 20130716000000.nc no LW-file for this day found
# 20130717000000.nc no LW-file for this day found
# 20130718000000.nc no LW-file for this day found
# 20130719000000.nc no LW-file for this day found
# 20130720000000.nc no LW-file for this day found
# 20130721000000.nc no LW-file for this day found
# 20130722000000.nc no LW-file for this day found
# 20130723000000.nc no LW-file for this day found
# 20130724000000.nc no LW-file for this day found
# 20130725000000.nc no LW-file for this day found
# 20130726000000.nc no LW-file for this day found
# 20130727000000.nc no LW-file for this day found
# 20130728000000.nc no LW-file for this day found
# 20130729000000.nc no LW-file for this day found
# 20130730000000.nc no LW-file for this day found
# 20130731000000.nc no LW-file for this day found
# 20130801000000.nc no LW-file for this day found
# 20130802000000.nc no LW-file for this day found
# 20130803000000.nc no LW-file for this day found
# 20130804000000.nc no LW-file for this day found
# 20130805000000.nc no LW-file for this day found
# 20130806000000.nc no LW-file for this day found
# 20130807000000.nc no LW-file for this day found
# 20130808000000.nc no LW-file for this day found
# 20130809000000.nc no LW-file for this day found
# 20130810000000.nc no LW-file for this day found
# 20130811000000.nc no LW-file for this day found
# 20130812000000.nc no LW-file for this day found
# 20130813000000.nc no LW-file for this day found
# 20130814000000.nc no LW-file for this day found
# 20130815000000.nc no LW-file for this day found
# 20130816000000.nc no LW-file for this day found
# 20130817000000.nc no LW-file for this day found
# 20130818000000.nc no LW-file for this day found
# 20130819000000.nc no LW-file for this day found
# 20130820000000.nc no LW-file for this day found
# 20130821000000.nc no LW-file for this day found
# 20130822000000.nc no LW-file for this day found
# 20130823000000.nc no LW-file for this day found
# 20130824000000.nc no LW-file for this day found
# 20130825000000.nc no LW-file for this day found
# 20130826000000.nc no LW-file for this day found
# 20130827000000.nc no LW-file for this day found
# 20130828000000.nc no LW-file for this day found
# 20130829000000.nc no LW-file for this day found
# 20130830000000.nc no LW-file for this day found
# 20130831000000.nc no LW-file for this day found
# 20130901000000.nc no LW-file for this day found
# 20130902000000.nc no LW-file for this day found
# 20130903000000.nc no LW-file for this day found
# 20130904000000.nc no LW-file for this day found
# 20130905000000.nc no LW-file for this day found
# 20130906000000.nc no LW-file for this day found
# 20130907000000.nc no LW-file for this day found
# 20130908000000.nc no LW-file for this day found
# 20130909000000.nc no LW-file for this day found
# 20130910000000.nc no LW-file for this day found
# 20130911000000.nc no LW-file for this day found
# 20130912000000.nc no LW-file for this day found
# 20130913000000.nc no LW-file for this day found
# 20130914000000.nc no LW-file for this day found
# 20130915000000.nc no LW-file for this day found
# 20130916000000.nc no LW-file for this day found
# 20130917000000.nc no LW-file for this day found
# 20130918000000.nc no LW-file for this day found
# 20130919000000.nc no LW-file for this day found
# 20130920000000.nc no LW-file for this day found
# 20130921000000.nc no LW-file for this day found
# 20130922000000.nc no LW-file for this day found
# 20130923000000.nc no LW-file for this day found
# 20130924000000.nc no LW-file for this day found
# 20130925000000.nc no LW-file for this day found
# 20130926000000.nc no LW-file for this day found
# 20130927000000.nc no LW-file for this day found
# 20130928000000.nc no LW-file for this day found
# 20130929000000.nc no LW-file for this day found
# 20130930000000.nc no LW-file for this day found
# 20131001000000.nc no SW-file for this day found
# 20131002000000.nc no SW-file for this day found
# 20131003000000.nc no SW-file for this day found
# 20131004000000.nc no SW-file for this day found
# 20131005000000.nc no SW-file for this day found
# 20131006000000.nc no SW-file for this day found
# 20131007000000.nc no SW-file for this day found
# 20131008000000.nc no SW-file for this day found
# 20131009000000.nc no SW-file for this day found
# 20131010000000.nc no SW-file for this day found
# 20131011000000.nc no SW-file for this day found
# 20131012000000.nc no SW-file for this day found
# 20131013000000.nc no SW-file for this day found
# 20131014000000.nc no SW-file for this day found
# 20131015000000.nc no SW-file for this day found
# 20131016000000.nc no SW-file for this day found
# 20131017000000.nc no SW-file for this day found
# 20131018000000.nc no SW-file for this day found
# 20131019000000.nc no SW-file for this day found
# 20131020000000.nc no SW-file for this day found
# 20131021000000.nc no SW-file for this day found
# 20131022000000.nc no SW-file for this day found
# 20131023000000.nc no SW-file for this day found
# 20131024000000.nc no SW-file for this day found
# 20131025000000.nc no SW-file for this day found
# 20131026000000.nc no SW-file for this day found
# 20131027000000.nc no SW-file for this day found
# 20131028000000.nc no SW-file for this day found
# 20131029000000.nc no SW-file for this day found
# 20131030000000.nc no SW-file for this day found
# 20131031000000.nc no SW-file for this day found
# 20131101000000.nc no SW-file for this day found
# 20131102000000.nc no SW-file for this day found
# 20131103000000.nc no SW-file for this day found
# 20131104000000.nc no SW-file for this day found
# 20131105000000.nc no SW-file for this day found
# 20131106000000.nc no SW-file for this day found
# 20131107000000.nc no SW-file for this day found
# 20131108000000.nc no SW-file for this day found
# 20131109000000.nc no SW-file for this day found
# 20131110000000.nc no SW-file for this day found
# 20131111000000.nc no SW-file for this day found
# 20131112000000.nc no SW-file for this day found
# 20131113000000.nc no SW-file for this day found
# 20131114000000.nc no SW-file for this day found
# 20131115000000.nc no SW-file for this day found
# 20131116000000.nc no SW-file for this day found
# 20131117000000.nc no SW-file for this day found
# 20131118000000.nc no SW-file for this day found
# 20131119000000.nc no SW-file for this day found
# 20131120000000.nc no SW-file for this day found
# 20131121000000.nc no SW-file for this day found
# 20131122000000.nc no SW-file for this day found
# 20131123000000.nc no SW-file for this day found
# 20131124000000.nc no SW-file for this day found
# 20131125000000.nc no SW-file for this day found
# 20131126000000.nc no SW-file for this day found
# 20131127000000.nc no SW-file for this day found
# 20131128000000.nc no SW-file for this day found
# 20131129000000.nc no SW-file for this day found
# 20131130000000.nc no SW-file for this day found
# 20131201000000.nc no SW-file for this day found
# 20131202000000.nc no SW-file for this day found
# 20131203000000.nc no SW-file for this day found
# 20131204000000.nc no SW-file for this day found
# 20131205000000.nc no SW-file for this day found
# 20131206000000.nc no SW-file for this day found
# 20131207000000.nc no SW-file for this day found
# 20131208000000.nc no SW-file for this day found
# 20131209000000.nc no SW-file for this day found
# 20131210000000.nc no SW-file for this day found
# 20131211000000.nc no SW-file for this day found
# 20131212000000.nc no SW-file for this day found
# 20131213000000.nc no SW-file for this day found
# 20131214000000.nc no SW-file for this day found
# 20131215000000.nc no SW-file for this day found
# 20131216000000.nc no SW-file for this day found
# 20131217000000.nc no SW-file for this day found
# 20131218000000.nc no SW-file for this day found
# 20131219000000.nc no SW-file for this day found
# 20131220000000.nc no SW-file for this day found
# 20131221000000.nc no SW-file for this day found
# 20131222000000.nc no SW-file for this day found
# 20131223000000.nc no SW-file for this day found
# 20131224000000.nc no SW-file for this day found
# 20131225000000.nc no SW-file for this day found
# 20131226000000.nc no SW-file for this day found
# 20131227000000.nc no SW-file for this day found
# 20131228000000.nc no SW-file for this day found
# 20131229000000.nc no SW-file for this day found
# 20131230000000.nc no SW-file for this day found
# 20131231000000.nc no SW-file for this day found
# 20140320000000.nc no LW-file for this day found
# 20140321000000.nc no LW-file for this day found
# 20140401000000.nc no LW-file for this day found
# /data/hatpro/jue/hdcp2/radiation_hdcp2/2014/sups_joy_pyrg00_l1_rlds_v01_20140407000000.nc  something went wrong with selecting sunlight time
# /data/hatpro/jue/hdcp2/radiation_hdcp2/2014/sups_joy_pyrg00_l1_rlds_v01_20140407000000.nc  something went wrong with selecting sunlight time
# 20140611000000.nc no LW-file for this day found
# 20151026000000.nc no LW-file for this day found
# 20151027000000.nc no LW-file for this day found
# 20151028000000.nc no LW-file for this day found
# 20151029000000.nc no LW-file for this day found
# 20151030000000.nc no LW-file for this day found
# 20151031000000.nc no LW-file for this day found
# 20151101000000.nc no LW-file for this day found
# 20151102000000.nc no LW-file for this day found
# 20151103000000.nc no LW-file for this day found
# 20151104000000.nc no LW-file for this day found
# /data/hatpro/jue/hdcp2/radiation_hdcp2/2016/sups_joy_pyrg00_l1_rlds_v01_20160325000000.nc  something went wrong with selecting sunlight time
# /data/hatpro/jue/hdcp2/radiation_hdcp2/2016/sups_joy_pyrg00_l1_rlds_v01_20160325000000.nc  something went wrong with selecting sunlight time
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2617893/2343104554.py in <module>
# ----> 1 select_daylight_data_juelich('2011-01-01', '2022-06-01', 'savings/')
#       2
#       3
#       4
#       5
#
# /tmp/ipykernel_2617893/1506099376.py in select_daylight_data_juelich(startdate, enddate, path)
#      74         fileObj_LW = Path(str(fileName_LW[0]))
#      75         if fileObj_LW.is_file() == True:
# ---> 76             ds_LW = xr.open_dataset(str(fileName_LW[0]))
#      77
#      78             #in a really few cases it didn't work out to select times (I guess something is wrong with the datasets). Nevertheless that the program doesent stop there is a try:...
#
# /usr/lib/python3/dist-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, backend_kwargs, *args, **kwargs)
#     493
#     494     overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 495     backend_ds = backend.open_dataset(
#     496         filename_or_obj,
#     497         drop_variables=drop_variables,
#
# /usr/lib/python3/dist-packages/xarray/backends/netCDF4_.py in open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     565         store_entrypoint = StoreBackendEntrypoint()
#     566         with close_on_error(store):
# --> 567             ds = store_entrypoint.open_dataset(
#     568                 store,
#     569                 mask_and_scale=mask_and_scale,
#
# /usr/lib/python3/dist-packages/xarray/backends/store.py in open_dataset(self, store, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta)
#      25         encoding = store.get_encoding()
#      26
# ---> 27         vars, attrs, coord_names = conventions.decode_cf_variables(
#      28             vars,
#      29             attrs,
#
# /usr/lib/python3/dist-packages/xarray/conventions.py in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     514             and stackable(v.dims[-1])
#     515         )
# --> 516         new_vars[k] = decode_cf_variable(
#     517             k,
#     518             v,
#
# /usr/lib/python3/dist-packages/xarray/conventions.py in decode_cf_variable(name, var, concat_characters, mask_and_scale, decode_times, decode_endianness, stack_char_dim, use_cftime, decode_timedelta)
#     362         var = times.CFTimedeltaCoder().decode(var, name=name)
#     363     if decode_times:
# --> 364         var = times.CFDatetimeCoder(use_cftime=use_cftime).decode(var, name=name)
#     365
#     366     dimensions, data, attributes, encoding = variables.unpack_for_decoding(var)
#
# /usr/lib/python3/dist-packages/xarray/coding/times.py in decode(self, variable, name)
#     671             units = pop_to(attrs, encoding, "units")
#     672             calendar = pop_to(attrs, encoding, "calendar")
# --> 673             dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
#     674             transform = partial(
#     675                 decode_cf_datetime,
#
# /usr/lib/python3/dist-packages/xarray/coding/times.py in _decode_cf_datetime_dtype(data, units, calendar, use_cftime)
#     168     values = indexing.ImplicitToExplicitIndexingAdapter(indexing.as_indexable(data))
#     169     example_value = np.concatenate(
# --> 170         [first_n_items(values, 1) or [0], last_item(values) or [0]]
#     171     )
#     172
#
# /usr/lib/python3/dist-packages/xarray/core/formatting.py in last_item(array)
#      95
#      96     indexer = (slice(-1, None),) * array.ndim
# ---> 97     return np.ravel(np.asarray(array[indexer])).tolist()
#      98
#      99
#
# /usr/lib/python3/dist-packages/xarray/core/indexing.py in __array__(self, dtype)
#     356
#     357     def __array__(self, dtype=None):
# --> 358         return np.asarray(self.array, dtype=dtype)
#     359
#     360     def __getitem__(self, key):
#
# /usr/lib/python3/dist-packages/xarray/core/indexing.py in __array__(self, dtype)
#     421     def __array__(self, dtype=None):
#     422         array = as_indexable(self.array)
# --> 423         return np.asarray(array[self.key], dtype=None)
#     424
#     425     def transpose(self, order):
#
# /usr/lib/python3/dist-packages/xarray/backends/netCDF4_.py in __getitem__(self, key)
#      91
#      92     def __getitem__(self, key):
# ---> 93         return indexing.explicit_indexing_adapter(
#      94             key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#      95         )
#
# /usr/lib/python3/dist-packages/xarray/core/indexing.py in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     710     """
#     711     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 712     result = raw_indexing_method(raw_key.tuple)
#     713     if numpy_indices.tuple:
#     714         # index the loaded np.ndarray
#
# /usr/lib/python3/dist-packages/xarray/backends/netCDF4_.py in _getitem(self, key)
#     104             with self.datastore.lock:
#     105                 original_array = self.get_array(needs_lock=False)
# --> 106                 array = getitem(original_array, key)
#     107         except IndexError:
#     108             # Catch IndexError in netCDF4 and return a more informative
#
# KeyboardInterrupt:

# %%
xr.open_dataset('savings1/2016/details20161006' + '.nc')
# Out:
# <xarray.Dataset>
# Dimensions:        (device_number: 2, time10s: 3337, time60s: 557)
# Coordinates:
#   * device_number  (device_number) uint8 1 2
#   * time10s        (time10s) datetime64[ns] 2016-10-06T08:44:00 ... 2016-10-0...
#   * time60s        (time60s) datetime64[ns] 2016-10-06T08:44:00 ... 2016-10-0...
# Data variables:
#     serial_number  (device_number) object ...
#     ocvv           (time10s, device_number) float32 ...
#     sccv           (time10s, device_number) float32 ...
#     mppvv          (time10s, device_number) float32 ...
#     mppcv          (time10s, device_number) float32 ...
#     irrv           (time10s) uint64 ...
#     mtv            (time10s, device_number) float32 ...
#     stv            (time10s, device_number) float32 ...
#     hst            (time60s, device_number) float32 ...
#     tem            (time60s, device_number) float32 ...
#     status         (time60s, device_number) uint8 ...
#     ivchar         (time60s, device_number) object ...
# Attributes:
#     desciption:  This nc file contains measurements of two photovoltaic modul...
#     history:     Created: 2017-07-13 12:48:14.163129
#     source:      /data/obs/site/jue/pvm/l1/2016/10/details20161006.txt.gz

# %%
import pandas as pd
import datetime as dt
from datetime import datetime, timedelta
from suntime import Sun, SunTimeException
from datetime import datetime, timezone
import numpy as np
import glob

import os
import pandas as pd
import xarray as xr
from pathlib import Path



def new_Dataset(startdate, enddate, path, endname):
    '''
    What does it?
    Step 4 from the Instructions:
    
    4. Saving data in array dataset instead of pandas data frame
        1. Iterate on a list of files from input
        2. Read also SW and LW downwelling, as well as direct/diffuse SW radiation
    
    
    -> In a timeperiod (between startdate and enddate) opens the daily datasets, puts all data (LW, LW_error, SW, SW_error) 
    into one dataset and selects the timstamps with sunlight.
    Saves it as a dataset in a given name and path. It creates new folders for every year if they do not already exist.
    
    
    input:
        - startdate: <string>: e.g.: '2020-01-01' 
        - enddate:   <string>: e.g.: '2020-03-02'
        - endname:   <string>: e.g.: 'all_data'  automaticlly appends the date of the day and an .nc at the end
        - path:      <string>: where to save the nc-file eg.: 'savings/'

        
    ''' 



    #Range of the datas
    all_dates = pd.date_range(start=startdate,end=enddate)



    #coordinates of Juelich
    latitude = 50.908546
    longitude = 6.413536
    sun = Sun(latitude, longitude)

    for day in all_dates:

        #get the day to string, to open the right file
        y = day.strftime('%Y')
        m = day.strftime('%m')
        d = day.strftime('%d')
        date = y + m + d + '000000.nc'

        #Open Files for LW and shortwave data and put them in one dataset
         #getting the names from the data. Some names have ..._v00_... and some ..._v01...
        fileName_lw = glob.glob('/data/hatpro/jue/hdcp2/radiation_hdcp2/'+ y +'/sups_joy_pyrg00_l1_rlds_v*_'+ date )
        #if there is no file for the day it goes to the next day
        if not fileName_lw:
            print(date + ' no LW-file for this day found')
            continue

        #open files 
        fileObj_lw = Path(str(fileName_lw[0]))
        if fileObj_lw.is_file() == True:
            ds_lw = xr.open_dataset(str(fileName_lw[0]),
                                   drop_variables = ['lon', 'lat'])

        else: 
            print('File not found', fileName_lw[0])
            continue

        #getting the names from the data. Some names have ..._v00_... and some ..._v01...
        fileName_sw = glob.glob('/data/hatpro/jue/hdcp2/radiation_hdcp2/'+ y +'/sups_joy_pyr00_l1_rsds_v*_'+ date )
        #if there is no file for the day it goes to the next day
        if not fileName_sw:
            print(date + ' no SW-file for this day found')
            continue

        #open files 
        fileObj_sw = Path(str(fileName_sw[0]))
        if fileObj_sw.is_file() == True:
            ds_sw = xr.open_dataset(str(fileName_sw[0]))
        else: 
            print('File not found', fileName_sw[0])
            continue

        #put the sw data to the lw data
        ds_lw['rsds'] = ds_sw['rsds']
        ds_lw['rsds_error'] = ds_sw['rsds_error']
        ds = ds_lw


        #getting the time of sunrise +1 hour and the time of sunset - 1 hour. (result has information of timezone)
        sur_tzd = sun.get_local_sunrise_time(day) + timedelta(hours=1)
        sus_tzd = sun.get_local_sunset_time(day) - timedelta(hours=1)

        #delete timezonedesignator (Data from sup_joys are in UTC)
        sur = sur_tzd.replace(tzinfo=None)
        sus = sus_tzd.replace(tzinfo=None)

        ds_light = ds.sel(time=slice(sur, sus))


        #checking if path/folder already exists
        MYDIR = (path + '/' + y)
        CHECK_FOLDER = os.path.isdir(MYDIR)

        # If folder doesn't exist, then create it.
        if not CHECK_FOLDER:
            os.makedirs(MYDIR)
            print("created folder : ", MYDIR)

        #saving it as a new dataset 
        save = path +'/'+ y + '/'+ endname + date 
        ds_light.to_netcdf(save)  


new_Dataset('2014-10-01', '2015-10-25', 'full_datasets', 'all_data')
# Out:
# created folder :  full_datasets/2014
# created folder :  full_datasets/2015

# %%
#how to open the dataset and read it to use it for the program

import xarray as xr
from pathlib import Path

startdate = '2020-01-01'
enddate = '2020-02-01'
path = 'savings/'
name = 'daylight'

#call function
timesteps_light_juelich(startdate, enddate, path, name)


fileName = path + name
fileObj = Path(fileName)
if fileObj.is_file() == True:
    ds = xr.open_dataset(fileName)
else: 
    print('File not found') 

dates = ds.date.data
hours = ds.hour.data
minutes = ds.minute.data

print(dates)
print(hours)
print(minutes)
# Out:
# ['20200101' '20200101' '20200101' ... '20200201' '20200201' '20200201']
# ['09' '09' '09' ... '16' '16' '16']
# ['40' '45' '50' ... '15' '20' '25']
